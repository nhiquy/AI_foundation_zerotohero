# %% [markdown]
# # Statistics and Applications

# %% [markdown]
# # Mean

# %%
def calculate_mean(numbers): #1
    s = sum(numbers)         #2
    N = len(numbers)         #3
    mean = s/N               #4
    return mean              #5

# Tao mang donations dai dien cho so tien quyen gop trong 12 ngay
donations = [100,60,70,900,100,200,500,500,503,600,1000,1200]

mean_value = calculate_mean(donations)
print('Trung binh so tien quyen gop la: ', mean_value)

# Dat ten la calculate_mean(), ham nay se nhan doi so numbers, la chuoi cac so can tinh trung binh.
# Su dung ham sum() de tinh tong day so cho truoc.
# Su dung ham len() de tinh chieu dai cua day so can tinh.
# Tinh trung binh cua day so tren bang cach lay tong chia cho chieu dai.
# Cuoi cung ta cho ham tra ve gia tri mean tinh duoc.

# %%
# Vi du khac:
def tinh_TB(numbers):
    s = sum(numbers)
    N = len(numbers)
    TB = s/N
    return TB
chieu_cao = [175,160,166,165,159,157,170,159,175,150]
chieu_cao_TB = tinh_TB(chieu_cao)
print('Chieu cao trung binh la: ', chieu_cao_TB)
# Out:
# Chieu cao trung binh la:  163.6

# %% [markdown]
# ## Correlation(convolution)
# #### Numpy: np.einsum()
# #### Scipy: scipy.signal.convolve2d()
# #### OpenCV: cv2.filter2D()

# %% [markdown]
# #### code: output_image = cv2.filter2D(input_image, cv2.CV_8U, kernel)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
image = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean.jpg',0)
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
import cv2
image = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean.jpg',0)
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
import sys
sys.path.append('./lib/python3/site-packages')
import numpy as np
import cv2
image = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean.jpg',0)
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
import cv2
image = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean.jpg',0)
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

#load image in grayscale mode
image = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean.jpg',0)

#create kernel
kernel = np.ones((5,5), np.float32) /25.0

# compute mean for each pixel
dst = cv2.filter2D(image, cv2.CV_8U, kernel)

#show image
cv2_imshow(image)
cv2_imshow(dst)


#waiting for any keys pressed and close windows
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=1292x726 at 0x7F481E1C5208>
# <PIL.Image.Image image mode=L size=1292x726 at 0x7F481E1B8A20>

# %% [markdown]
# ### Image Blurring

# %%
# load image and blurring using mask-simple

import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# load image in grayscale mode
image = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean.jpg', 0)

# create kernel
kernel = np.ones((5,5), np.float32) / 25.0

# Select ROI (top_y,top_x,height, width)
roi = image[40:140,150:280]

# compute mean for each pixel
roi = cv2.filter2D(roi, cv2.CV_8U, kernel)

image[40:140,150:280] = roi

# show images
cv2_imshow(roi)
cv2_imshow(image)

# waiting for any keys pressed and close windows
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=130x100 at 0x7F481E141A58>
# <PIL.Image.Image image mode=L size=1292x726 at 0x7F481E141A90>

# %%
#load image and blurring using mask-simple
import numpy as np
import cv2
from google.colab.patches import cv2_imshow


#load image in grayscale mode
image = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean.jpg', 0)

#create kernel
kernel = np.ones((5,5), np.float32) /25.0

#Select ROI (top_y, top_x, height, width)
roi = image [40:140, 150:280]

#compute mean for each pixel
roi = cv2.filter2D(roi, cv2.CV_8U, kernel)

image[40:140, 150:280] = roi

#show images
cv2_imshow(roi)
cv2_imshow(image)

#waiting for any keys pressed and close windows
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=130x100 at 0x7F481E15BBE0>
# <PIL.Image.Image image mode=L size=1292x726 at 0x7F481E15B630>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# To capture video from webcam. 
cap = cv2.VideoCapture(0)

# create kernel
kernel = np.ones((7,7), np.float32) / 49.0

while True:
    success, img = cap.read()
    if img is None:
        break
    imgResult = img.copy()
#while True:
    # Read the frame
   # _, img = cap.read()
    #img2 = img.copy()
    
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    
    # Draw the rectangle around each face
    for (x, y, w, h) in faces:
        # Select ROI (top_y,top_x,height, width)
        roi = img[y-10:y+h+10,x-10:x+w+10]

        # compute mean for each pixel
        roi = cv2.filter2D(roi, cv2.CV_8U, kernel)
        roi = cv2.filter2D(roi, cv2.CV_8U, kernel)
        roi = cv2.filter2D(roi, cv2.CV_8U, kernel)

        # update
        img[y-10:y+h+10,x-10:x+w+10] = roi
    
    # Display
    cv2_imshow(img)
    cv2_imshow(imgResult)
    
    # Stop if escape key is pressed
    key = cv2.waitKey(30) & 0xff
    if key==27:
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Stereo matching

# %% [markdown]
# # Median

# %%
# Code
def calculate_median(numbers):
    N = len(numbers)
    numbers.sort()
    if N%2 == 0:
        m1 = N/2
        m2 = (N/2)+1
        m1 = int(m1)-1
        m2 = int(m2)-1
        median = (numbers[m1] + numbers[m2])/2
    else:
        m = (N+1)/2
        m = int(m)-1
        median = numbers[m]
    return median

# %%
calculate_median([1,2,3,4])
# Out:
# 2.5

# %% [markdown]
# ### Applications
# #### 1. Image Denoising

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

img1 = cv2.imread('/content/drive/My Drive/AI_foundation/mrbean_noise.jpg')
img2 = cv2.medianBlur(img1, 3)

# show images
cv2_imshow(img1)
cv2_imshow(img2)

# waiting for any keys pressed and close windows
cv2.waitKey
cv2.destroyAllWindows
# Out:
# <PIL.Image.Image image mode=RGB size=435x326 at 0x7F481E15EDD8>
# <PIL.Image.Image image mode=RGB size=435x326 at 0x7F481E156400>
# <function destroyAllWindows>

# %% [markdown]
# # Range and Histogram
# ### Procedure

# %%
def find_range(numbers):
  lowest = min(numbers)
  highest = max(numbers)
  r = highest - lowest
  print('Lowest: {0}\tHighest: {1}\tRange: {2}'.format(lowest, highest, r))

# %%
#data
points = [7,8,9,2,1,2,3,4,5,7,8,9,5,4,-1]
find_range(points)
# Out:
# Lowest: -1	Highest: 9	Range: 10

# %% [markdown]
# #### Histogram of grayscale image

# %% [markdown]
# Pixel
# có 256 giá trị khác nhau (từ 0 đến 255) -->chia thành 256 bin . Mỗi bin chứa (đếm) số lượng pixel có cùng giá trị.

# %% [markdown]
# ![](/content/drive/My Drive/AI_foundation/Histogram_grayscale.PNG)

# %% [markdown]
# Gọi N là tổng số pixel của ảnh và $𝑛_𝑏$là số lượng pixel ở bin thứ b.
# Giá trị density histogram ở bin thứ b được tính như sau:
# $$ℎ[𝑏]=\dfrac{𝑛_𝑏}{𝑁}.$$
# Giá trị cumulative histogram ở bin thứ b được tính như sau:
# $$H[b] = \sum_{k=0}^b h[k]$$
# /content/drive/My Drive/AI_foundation/Histogram_Density_Cumulative.PNG

# %% [markdown]
# ### Histogram equalization
# * Được dùng để tăng độ tương phản của ảnh
# * Idea:
# Kéo phân bố của density histogram sao cho xấp xỉ với uniform distribution.
# Công thức:
# $$b_{new} = [255*H[b]+0.5]$$
# * ! note: Các bin (giá trị của pixel) được thay đổi theo $H[b]$.

# %% [markdown]
# # Variance
# Mean $$\mu = \dfrac{1}{n}\sum_{k=1}^n x_i $$
#
# Variance $$var(X) = \dfrac{1}{n}\sum_{k=1}^n (x_i - \mu)^2 $$
#
# Standard deviation $$\sigma = \sqrt(var(X))$$

# %%
# Code
def calculate_mean(numbers):
  s = sum(numbers)
  N = len(numbers)
  mean = s/N
  return mean
def calculate_variance(numbers):
   mean = calculate_mean(numbers)

   diff = []
   for num in numbers:
     diff.append(num-mean)

   squared_diff = []
   for d in diff:
     squared_diff.append(d**2)

   sum_squared_diff = sum(squared_diff)
   variance = sum_squared_diff/len(numbers)

   return variance

# %%
calculate_mean([1,2,3,4,5])
# Out:
# 3.0

# %%
calculate_variance([3,4,5,6,7])
# Out:
# 2.0

# %% [markdown]
# Ứng dụng tính chất của variance (standard deviation) để tìm texture cho một hình.

# %% [markdown]
# ### Implementation

# %%
import numpy as np
import cv2
import math
from scipy.ndimage.filters import generic_filter

img = cv2.imread('/content/drive/My Drive/AI_foundation/img.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imwrite('/content/drive/My Drive/AI_foundation/edge_s2.jpg', gray)

x = gray.astype('float')
x_filt = generic_filter(x, np.std, size =7)
cv2.imwrite('/content/drive/My Drive/AI_foundation/edge_s2.jpg', x_filt)

x_filt[x_filt < 20] = 0
cv2.imwrite('/content/drive/My Drive/AI_foundation/edge_s3.jpg',x_filt)

maxv = np.max(x_filt)
print(maxv)

x_filt = x_filt*2.5
cv2.imwrite('/content/drive/My Drive/AI_foundation/edge_s4.jpg', x_filt)
# Out:
# 97.80697358385369
# True

# %% [markdown]
# # Correlation Coefficient

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# To capture video from webcam. 
cap = cv2.VideoCapture(0)

# select region
while True:
    # Read the frame and Convert to grayscale
    _, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    top_left = (200,300)
    bottom_right = (400,400)
    cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)

    
    # Display
    cv2_imshow(img)
    
    # press the 'a' key
    if cv2.waitKey(33) == ord('a'):  
        break

# create a template
template = gray[300:400, 200:400]
w, h = template.shape[::-1]
cv2_imshow( template)
cv2.waitKey(0) # press any keys

# tracking
while True:
    # Read the frame and Convert to grayscale
    _, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        
    corr_map = cv2.matchTemplate(gray, template, cv2.TM_CCOEFF_NORMED)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(corr_map) 

    # take minimum
    top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)

    # draw 
    cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)

    
    # Display
    cv2_imshow(img)
    
    # press the 'a' key
    if cv2.waitKey(33) == ord('a'):  
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-80bb55b99c02> in <module>()
#       9     # Read the frame and Convert to grayscale
#      10     _, img = cap.read()
# ---> 11     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      12
#      13     top_left = (200,300)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
